# %%
# Carregando as bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# carregando os arquivos renomeando as colunas.
df = pd.read_csv("C:/Users/chavi/Downloads/202201_CPGF.csv",encoding="latin1",sep =";", names=["Cod_Orgao_Superior", "Orgao_Superior", "Cod_Orgao","Orgao", "Cod_Unid_Gestora", "Unid_Gestora","Ano_Extrato","Mes_Extrato","CPF_Portador","Portador","CPF_CNPJ_Favorecido","Favorecido", "Transacao", "Data_Transacao", "Valor_Transacao"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8628 entries, 0 to 8627
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_Orgao_Superior   8628 non-null   int64
#  1   Orgao_Superior       8628 non-null   object
#  2   Cod_Orgao            8628 non-null   int64
#  3   Orgao                8628 non-null   object
#  4   Cod_Unid_Gestora     8628 non-null   int64
#  5   Unid_Gestora         8628 non-null   object
#  6   Ano_Extrato          8628 non-null   int64
#  7   Mes_Extrato          8628 non-null   int64
#  8   CPF_Portador         6537 non-null   object
#  9   Portador             8628 non-null   object
#  10  CPF_CNPJ_Favorecido  8628 non-null   int64
#  11  Favorecido           8628 non-null   object
#  12  Transacao            8628 non-null   object
#  13  Data_Transacao       6554 non-null   object
#  14  Valor_Transacao      8628 non-null   float64
# ...

# %%
# Resumo de Linhas e Colunas
df.shape
# Out:
# (8628, 15)

# %%
#Lista de colunas contidas no DataFrame
df.columns
# Out:
# Index(['Cod_Orgao_Superior', 'Orgao_Superior', 'Cod_Orgao', 'Orgao',
#        'Cod_Unid_Gestora', 'Unid_Gestora', 'Ano_Extrato', 'Mes_Extrato',
#        'CPF_Portador', 'Portador', 'CPF_CNPJ_Favorecido', 'Favorecido',
#        'Transacao', 'Data_Transacao', 'Valor_Transacao'],
#       dtype='object')

# %%
df.head()
# Out:
#    Cod_Orgao_Superior            Orgao_Superior  Cod_Orgao  \
# 0               63000  Advocacia-Geral da União      63000
# 1               63000  Advocacia-Geral da União      63000
# 2               63000  Advocacia-Geral da União      63000
# 3               63000  Advocacia-Geral da União      63000
# 4               63000  Advocacia-Geral da União      63000
#
#                                                Orgao  Cod_Unid_Gestora  \
# 0  Advocacia-Geral da União - Unidades com víncul...            110096
# 1  Advocacia-Geral da União - Unidades com víncul...            110096
# 2  Advocacia-Geral da União - Unidades com víncul...            110096
# 3  Advocacia-Geral da União - Unidades com víncul...            110096
# 4  Advocacia-Geral da União - Unidades com víncul...            110096
#
#                                    Unid_Gestora  Ano_Extrato  Mes_Extrato  \
# 0  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2022            1
# ...

# %%
df.tail()
# Out:
#       Cod_Orgao_Superior            Orgao_Superior  Cod_Orgao  \
# 8623               20000  Presidência da República      20101
# 8624               20000  Presidência da República      20101
# 8625               20000  Presidência da República      20101
# 8626               20000  Presidência da República      20101
# 8627               20000  Presidência da República      20101
#
#                          Orgao  Cod_Unid_Gestora  \
# 8623  Presidência da República            110001
# 8624  Presidência da República            110001
# 8625  Presidência da República            110001
# 8626  Presidência da República            110001
# 8627  Presidência da República            110001
#
#                                  Unid_Gestora  Ano_Extrato  Mes_Extrato  \
# 8623  SECRETARIA ESPECIAL DE ADMINISTRACAO/PR         2022            1
# 8624  SECRETARIA ESPECIAL DE ADMINISTRACAO/PR         2022            1
# 8625  SECRETARIA ESPECIAL DE ADMINISTRACAO/PR         2022            1
# ...

# %%
df.dropna(axis=0).head()
# Out:
#    Cod_Orgao_Superior            Orgao_Superior  Cod_Orgao  \
# 0               63000  Advocacia-Geral da União      63000
# 1               63000  Advocacia-Geral da União      63000
# 2               63000  Advocacia-Geral da União      63000
# 3               63000  Advocacia-Geral da União      63000
# 4               63000  Advocacia-Geral da União      63000
#
#                                                Orgao  Cod_Unid_Gestora  \
# 0  Advocacia-Geral da União - Unidades com víncul...            110096
# 1  Advocacia-Geral da União - Unidades com víncul...            110096
# 2  Advocacia-Geral da União - Unidades com víncul...            110096
# 3  Advocacia-Geral da União - Unidades com víncul...            110096
# 4  Advocacia-Geral da União - Unidades com víncul...            110096
#
#                                    Unid_Gestora  Ano_Extrato  Mes_Extrato  \
# 0  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2022            1
# ...

# %%
df.isnull()
# Out:
#       Cod_Orgao_Superior  Orgao_Superior  Cod_Orgao  Orgao  Cod_Unid_Gestora  \
# 0                  False           False      False  False             False
# 1                  False           False      False  False             False
# 2                  False           False      False  False             False
# 3                  False           False      False  False             False
# 4                  False           False      False  False             False
# ...                  ...             ...        ...    ...               ...
# 8623               False           False      False  False             False
# 8624               False           False      False  False             False
# 8625               False           False      False  False             False
# 8626               False           False      False  False             False
# 8627               False           False      False  False             False
#
# ...

# %%
df.fillna(0,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8628 entries, 0 to 8627
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_Orgao_Superior   8628 non-null   int64
#  1   Orgao_Superior       8628 non-null   object
#  2   Cod_Orgao            8628 non-null   int64
#  3   Orgao                8628 non-null   object
#  4   Cod_Unid_Gestora     8628 non-null   int64
#  5   Unid_Gestora         8628 non-null   object
#  6   Ano_Extrato          8628 non-null   int64
#  7   Mes_Extrato          8628 non-null   int64
#  8   CPF_Portador         8628 non-null   object
#  9   Portador             8628 non-null   object
#  10  CPF_CNPJ_Favorecido  8628 non-null   int64
#  11  Favorecido           8628 non-null   object
#  12  Transacao            8628 non-null   object
#  13  Data_Transacao       8628 non-null   object
#  14  Valor_Transacao      8628 non-null   float64
# ...

# %%
# Alteração Dtype campo/variavel "Data_Transação"
df["Data_Transacao"] = pd.to_datetime(df["Data_Transacao"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8628 entries, 0 to 8627
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_Orgao_Superior   8628 non-null   int64
#  1   Orgao_Superior       8628 non-null   object
#  2   Cod_Orgao            8628 non-null   int64
#  3   Orgao                8628 non-null   object
#  4   Cod_Unid_Gestora     8628 non-null   int64
#  5   Unid_Gestora         8628 non-null   object
#  6   Ano_Extrato          8628 non-null   int64
#  7   Mes_Extrato          8628 non-null   int64
#  8   CPF_Portador         8628 non-null   object
#  9   Portador             8628 non-null   object
#  10  CPF_CNPJ_Favorecido  8628 non-null   int64
#  11  Favorecido           8628 non-null   object
#  12  Transacao            8628 non-null   object
#  13  Data_Transacao       8628 non-null   datetime64[ns]
#  14  Valor_Transacao      8628 non-null   float64
# ...

# %%
# Relação de Códigos de Orgão Superior
(df["Cod_Orgao_Superior"].unique())
# Out:
# array([63000, 25201, 37000, 22000, 24000, 52000, 25000, 26000, 39000,
#        30000, 81000, 36000, 41000, 35000, 32000, 53000, 44000, 40000,
#        38000, 54000, 20000], dtype=int64)

# %%
# Relaçao de Orgãos Superiores por Nome
(df["Orgao_Superior"].unique())
# Out:
# array(['Advocacia-Geral da União',
#        'Banco Central do Brasil - Orcamento Fiscal',
#        'Controladoria Geral da União',
#        'Ministério da Agricultura, Pecuária e Abastecimento',
#        'Ministério da Ciência, Tecnologia, Inovações',
#        'Ministério da Defesa', 'Ministério da Economia',
#        'Ministério da Educação', 'Ministério da Infraestrutura',
#        'Ministério da Justiça e Segurança Pública',
#        'Ministério da Mulher, Família e Direitos Huma',
#        'Ministério da Saúde', 'Ministério das Comunicações',
#        'Ministério das Relações Exteriores',
#        'Ministério de Minas e Energia',
#        'Ministério do Desenvolvimento Regional',
#        'Ministério do Meio Ambiente', 'Ministério do Trabalho',
#        'Ministério do Trabalho e Emprego', 'Ministério do Turismo',
#        'Presidência da República'], dtype=object)

# %%
# Correção de Nome coluna Orgão Superior
df["Orgao_Superior"].replace(["Banco Central do Brasil - Orçamento Fiscal e ", "Controladoria-Geral da União","Ministério da Agricultura, Pecuária e Abastec", "Ministério da Ciência, Tecnologia, Inovações " ], ["Banco Central do Brasil - Orcamento Fiscal", "Controladoria Geral da União", "Ministério da Agricultura, Pecuária e Abastecimento", "Ministério da Ciência, Tecnologia, Inovações"], inplace=True)
(df["Orgao_Superior"].unique())
# Out:
# array(['Advocacia-Geral da União',
#        'Banco Central do Brasil - Orcamento Fiscal',
#        'Controladoria Geral da União',
#        'Ministério da Agricultura, Pecuária e Abastecimento',
#        'Ministério da Ciência, Tecnologia, Inovações',
#        'Ministério da Defesa', 'Ministério da Economia',
#        'Ministério da Educação', 'Ministério da Infraestrutura',
#        'Ministério da Justiça e Segurança Pública',
#        'Ministério da Mulher, Família e Direitos Huma',
#        'Ministério da Saúde', 'Ministério das Comunicações',
#        'Ministério das Relações Exteriores',
#        'Ministério de Minas e Energia',
#        'Ministério do Desenvolvimento Regional',
#        'Ministério do Meio Ambiente', 'Ministério do Trabalho',
#        'Ministério do Trabalho e Emprego', 'Ministério do Turismo',
#        'Presidência da República'], dtype=object)

# %%
# Relação de Orgãos por código
df["Cod_Orgao"].unique()
# Out:
# array([63000, 25201, 37000, 22211, 22202, 22201, 22000, 20402, 20301,
#        20501, 24000, 52111, 52121, 52904, 52221, 52000, 25203, 25205,
#        25915, 61201, 30203, 25000, 20603, 26257, 26201, 26443, 26292,
#        26271, 26284, 26278, 26281, 26280, 26279, 26230, 26294, 26404,
#        26422, 26417, 26402, 26409, 26421, 26437, 26438, 26439, 26403,
#        26406, 26408, 26414, 26415, 26432, 26431, 26435, 26419, 26424,
#        26413, 26407, 26440, 26267, 26260, 26235, 26237, 26263, 26277,
#        26242, 26247, 26245, 26243, 26255, 26249, 26264, 26258, 62201,
#        68201, 39250, 39252, 39253, 30211, 30108, 30802, 30907, 30000,
#        81000, 36213, 36212, 36211, 36201, 36210, 36000, 41231, 20415,
#        41000, 24216, 35201, 35000, 32210, 32396, 32205, 29208, 32314,
#        32000, 44205, 29214, 22203, 22204, 53000, 53202, 53203, 20701,
#        44207, 44206, 44000, 38901, 37202, 40000, 38000, 20203, 20408,
#        20412, 20411, 60000, 24208, 20101], dtype=int64)

# %%
# Relação de Orgãos por Nome
display(df["Orgao"].unique())
# Out:
# array(['Advocacia-Geral da União - Unidades com vínculo direto',
#        'Banco Central do Brasil - Orçamento Fiscal e Seguridade Social - Unidades com vínculo direto',
#        'Controladoria-Geral da União - Unidades com vínculo direto',
#        'Companhia Nacional de Abastecimento',
#        'Empresa Brasileira de Pesquisa Agropecuária',
#        'Instituto Nacional de Colonização e Reforma Agrária',
#        'Ministério da Agricultura, Pecuária e Abastecimento - Unidades com vínculo direto',
#        'Agência Espacial Brasileira',
#        'Comissão Nacional de Energia Nuclear',
#        'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#        'Ministério da Ciência, Tecnologia, Inovações e Comunicações - Unidades com vínculo direto',
#        'Comando da Aeronáutica', 'Comando do Exército',
#        'Fundo do Exército', 'Indústria de Material Bélico do Brasil',
#        'Ministério da Defesa - Unidades com vínculo direto',
# ...

# %%
# Filtro Colunas Cod_Orgao_Superior == 6300 indexada pelo valor da Transação
df.loc[df["Cod_Orgao_Superior"]==63000,["Cod_Orgao_Superior","Orgao_Superior","Valor_Transacao"]].sort_values(by=["Valor_Transacao"],ascending=True)
# Out:
#     Cod_Orgao_Superior            Orgao_Superior  Valor_Transacao
# 17               63000  Advocacia-Geral da União             9.00
# 27               63000  Advocacia-Geral da União            20.00
# 7                63000  Advocacia-Geral da União            28.00
# 8                63000  Advocacia-Geral da União            33.00
# 52               63000  Advocacia-Geral da União            35.00
# 11               63000  Advocacia-Geral da União            37.00
# 48               63000  Advocacia-Geral da União            40.60
# 20               63000  Advocacia-Geral da União            54.00
# 47               63000  Advocacia-Geral da União            60.00
# 51               63000  Advocacia-Geral da União            75.99
# 34               63000  Advocacia-Geral da União            80.00
# 12               63000  Advocacia-Geral da União            82.00
# 53               63000  Advocacia-Geral da União            90.00
# ...

# %%
# Filtro Valor transacao maior que 500 e menor que 3000
df[(df["Valor_Transacao"]>500.00) & (df["Valor_Transacao"]<3000.00)]
# Out:
#       Cod_Orgao_Superior            Orgao_Superior  Cod_Orgao  \
# 0                  63000  Advocacia-Geral da União      63000
# 2                  63000  Advocacia-Geral da União      63000
# 3                  63000  Advocacia-Geral da União      63000
# 5                  63000  Advocacia-Geral da União      63000
# 14                 63000  Advocacia-Geral da União      63000
# ...                  ...                       ...        ...
# 8605               20000  Presidência da República      20101
# 8606               20000  Presidência da República      20101
# 8608               20000  Presidência da República      20101
# 8609               20000  Presidência da República      20101
# 8611               20000  Presidência da República      20101
#
#                                                   Orgao  Cod_Unid_Gestora  \
# 0     Advocacia-Geral da União - Unidades com víncul...            110096
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8628 entries, 0 to 8627
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_Orgao_Superior   8628 non-null   int64
#  1   Orgao_Superior       8628 non-null   object
#  2   Cod_Orgao            8628 non-null   int64
#  3   Orgao                8628 non-null   object
#  4   Cod_Unid_Gestora     8628 non-null   int64
#  5   Unid_Gestora         8628 non-null   object
#  6   Ano_Extrato          8628 non-null   int64
#  7   Mes_Extrato          8628 non-null   int64
#  8   CPF_Portador         8628 non-null   object
#  9   Portador             8628 non-null   object
#  10  CPF_CNPJ_Favorecido  8628 non-null   int64
#  11  Favorecido           8628 non-null   object
#  12  Transacao            8628 non-null   object
#  13  Data_Transacao       8628 non-null   datetime64[ns]
#  14  Valor_Transacao      8628 non-null   float64
# ...

# %%
# Filtro por orgão com valor de transação em ordem crescente
df.loc[df["Orgao"]=="Gabinete da Vice-Presidência da República", ["Cod_Orgao","Orgao","Valor_Transacao"]].sort_values(by=["Valor_Transacao"],ascending=True)
# Out:
#       Cod_Orgao                                      Orgao  Valor_Transacao
# 7787      60000  Gabinete da Vice-Presidência da República            14.00
# 7788      60000  Gabinete da Vice-Presidência da República            18.00
# 7781      60000  Gabinete da Vice-Presidência da República            19.60
# 7760      60000  Gabinete da Vice-Presidência da República            20.00
# 7842      60000  Gabinete da Vice-Presidência da República            29.75
# ...         ...                                        ...              ...
# 7757      60000  Gabinete da Vice-Presidência da República          5375.70
# 7768      60000  Gabinete da Vice-Presidência da República          7000.00
# 7792      60000  Gabinete da Vice-Presidência da República          7427.00
# 7776      60000  Gabinete da Vice-Presidência da República          8504.25
# 7778      60000  Gabinete da Vice-Presidência da República         10000.00
#
# [106 rows x 3 columns]

# %%
#Filtro por orgao superior contendo data e transaçao por ordem crescente
df.loc[df["Orgao_Superior"]=="Ministério de Minas e Energia",["Cod_Orgao_Superior","Orgao_Superior","Data_Transacao", "Valor_Transacao"]].sort_values(by=["Valor_Transacao"],ascending=True)
# Out:
#       Cod_Orgao_Superior                 Orgao_Superior Data_Transacao  \
# 6914               32000  Ministério de Minas e Energia     2021-11-27
# 6935               32000  Ministério de Minas e Energia     2021-06-12
# 6900               32000  Ministério de Minas e Energia     2021-12-13
# 6865               32000  Ministério de Minas e Energia     2021-11-29
# 6953               32000  Ministério de Minas e Energia     2021-02-12
# ...                  ...                            ...            ...
# 6818               32000  Ministério de Minas e Energia     2021-12-14
# 6871               32000  Ministério de Minas e Energia     2021-02-12
# 6760               32000  Ministério de Minas e Energia     2021-12-13
# 6858               32000  Ministério de Minas e Energia     2021-02-12
# 6879               32000  Ministério de Minas e Energia     2021-11-30
#
#       Valor_Transacao
# 6914             4.99
# 6935             6.00
# 6900             6.00
# ...

# %%
df[df["Cod_Orgao_Superior"]==63000]
# Out:
#     Cod_Orgao_Superior            Orgao_Superior  Cod_Orgao  \
# 0                63000  Advocacia-Geral da União      63000
# 1                63000  Advocacia-Geral da União      63000
# 2                63000  Advocacia-Geral da União      63000
# 3                63000  Advocacia-Geral da União      63000
# 4                63000  Advocacia-Geral da União      63000
# 5                63000  Advocacia-Geral da União      63000
# 6                63000  Advocacia-Geral da União      63000
# 7                63000  Advocacia-Geral da União      63000
# 8                63000  Advocacia-Geral da União      63000
# 9                63000  Advocacia-Geral da União      63000
# 10               63000  Advocacia-Geral da União      63000
# 11               63000  Advocacia-Geral da União      63000
# 12               63000  Advocacia-Geral da União      63000
# 13               63000  Advocacia-Geral da União      63000
# 14               63000  Advocacia-Geral da União      63000
# ...

# %%
#Filtro de dois campos simultaneamente organizados de forma ascendente pelo valor da transação
df.loc[(df["Orgao_Superior"]=="Ministério da Economia")&(df["Cod_Unid_Gestora"]==173030),["Cod_Orgao_Superior","Orgao_Superior","Cod_Orgao","Orgao","Data_Transacao","Valor_Transacao"]].sort_values(by=["Valor_Transacao"],ascending=True)
# Out:
#       Cod_Orgao_Superior          Orgao_Superior  Cod_Orgao  \
# 1824               25000  Ministério da Economia      25203
# 1822               25000  Ministério da Economia      25203
# 1823               25000  Ministério da Economia      25203
# 1821               25000  Ministério da Economia      25203
#
#                                 Orgao Data_Transacao  Valor_Transacao
# 1824  Comissão de Valores Mobiliários     2021-12-22            55.70
# 1822  Comissão de Valores Mobiliários     2021-11-29            82.90
# 1823  Comissão de Valores Mobiliários     2021-06-12            97.50
# 1821  Comissão de Valores Mobiliários     2021-11-29          1656.54

# %%
# Média e Mediana Valor_Transacao
print(df["Valor_Transacao"].mean())
print(df["Valor_Transacao"].median())
# Out:
# 715.7533414464534
# 376.905

# %%
#Contagem de Orgãos Superiores
df["Orgao_Superior"].value_counts()
# Out:
# Ministério da Economia                                 2381
# Ministério da Justiça e Segurança Pública              1414
# Ministério da Agricultura, Pecuária e Abastecimento     935
# Presidência da República                                887
# Ministério da Educação                                  753
# Ministério da Defesa                                    615
# Ministério da Saúde                                     308
# Ministério do Meio Ambiente                             273
# Ministério de Minas e Energia                           231
# Ministério do Trabalho                                  217
# Ministério do Desenvolvimento Regional                  215
# Ministério da Ciência, Tecnologia, Inovações            146
# Banco Central do Brasil - Orcamento Fiscal               66
# Advocacia-Geral da União                                 55
# Ministério do Trabalho e Emprego                         37
# Ministério da Infraestrutura                             32
# ...

# %%
#Resumo estatístico varivel/campo numérico Valor_Transacao
df[["Valor_Transacao"]].describe()
# Out:
#        Valor_Transacao
# count      8628.000000
# mean        715.753341
# std        2304.352491
# min           1.000000
# 25%         135.950000
# 50%         376.905000
# 75%        1000.000000
# max       70000.000000

# %%
#Correlacao entre campos DataFrame df
df.corr()
# Out:
#                      Cod_Orgao_Superior  Cod_Orgao  Cod_Unid_Gestora  \
# Cod_Orgao_Superior             1.000000   0.762527          0.320192
# Cod_Orgao                      0.762527   1.000000          0.236944
# Cod_Unid_Gestora               0.320192   0.236944          1.000000
# Ano_Extrato                         NaN        NaN               NaN
# Mes_Extrato                         NaN        NaN               NaN
# CPF_CNPJ_Favorecido            0.076281   0.037057          0.095424
# Valor_Transacao               -0.061042  -0.037589         -0.050394
#
#                      Ano_Extrato  Mes_Extrato  CPF_CNPJ_Favorecido  \
# Cod_Orgao_Superior           NaN          NaN             0.076281
# Cod_Orgao                    NaN          NaN             0.037057
# Cod_Unid_Gestora             NaN          NaN             0.095424
# Ano_Extrato                  NaN          NaN                  NaN
# Mes_Extrato                  NaN          NaN                  NaN
# ...

# %%
df.groupby("Orgao_Superior").sum()
# Out:
#                                                     Cod_Orgao_Superior  \
# Orgao_Superior
# Advocacia-Geral da União                                       3465000
# Banco Central do Brasil - Orcamento Fiscal                     1663266
# Controladoria Geral da União                                    148000
# Ministério da Agricultura, Pecuária e Abastecim...            20570000
# Ministério da Ciência, Tecnologia, Inovações                   3504000
# Ministério da Defesa                                          31980000
# Ministério da Economia                                        59525000
# Ministério da Educação                                        19578000
# Ministério da Infraestrutura                                   1248000
# Ministério da Justiça e Segurança Pública                     42420000
# Ministério da Mulher, Família e Direitos Huma                    81000
# Ministério da Saúde                                           11088000
# ...

# %%
df.groupby("Orgao").sum()
# Out:
#                                                     Cod_Orgao_Superior  \
# Orgao
# Advocacia-Geral da União - Unidades com vínculo...             3465000
# Agência Espacial Brasileira                                      72000
# Agência Nacional de Aviação Civil                               156000
# Agência Nacional de Energia Elétrica                            224000
# Agência Nacional de Mineração                                  3424000
# ...                                                                ...
# Universidade Federal de Santa Maria                            1378000
# Universidade Federal do Rio Grande do Norte                      78000
# Universidade Federal do Rio de Janeiro                          364000
# Universidade Federal dos Vales do Jequitinhonha...              156000
# Universidade Tecnológica Federal do Paraná                      364000
#
#                                                     Cod_Orgao  \
# Orgao
# ...

# %%
df.groupby(["Orgao_Superior","Valor_Transacao"]).sum()
# Out:
#                                           Cod_Orgao_Superior  Cod_Orgao  \
# Orgao_Superior           Valor_Transacao
# Advocacia-Geral da União 9.00                          63000      63000
#                          20.00                         63000      63000
#                          28.00                         63000      63000
#                          33.00                         63000      63000
#                          35.00                         63000      63000
# ...                                                      ...        ...
# Presidência da República 44826.76                      20000      20101
#                          50148.00                      20000      20101
#                          65000.00                      20000      20101
#                          67936.70                      20000      20101
#                          70000.00                      20000      20101
#
# ...

# %%
df.groupby("Valor_Transacao").mean()
# Out:
#                  Cod_Orgao_Superior  Cod_Orgao  Cod_Unid_Gestora  Ano_Extrato  \
# Valor_Transacao
# 1.00                        52000.0    52121.0          160167.5       2022.0
# 3.40                        25000.0    25205.0          114614.0       2022.0
# 3.60                        25000.0    25000.0          170190.0       2022.0
# 4.75                        26000.0    26247.0          153164.0       2022.0
# 4.99                        32000.0    29208.0          495550.0       2022.0
# ...                             ...        ...               ...          ...
# 44826.76                    20000.0    20101.0          110001.0       2022.0
# 50148.00                    20000.0    20101.0          110001.0       2022.0
# 65000.00                    20000.0    20101.0          110001.0       2022.0
# 67936.70                    20000.0    20101.0          110001.0       2022.0
# 70000.00                    20000.0    20101.0          110001.0       2022.0
#
# ...

# %%
# Indexação por orgaos com media do valor de transacao
pd.pivot_table(df,values="Valor_Transacao",  index=["Orgao_Superior", "Orgao"], aggfunc="mean", margins=True)
# Out:
#                                                                                                        Valor_Transacao
# Orgao_Superior                                     Orgao
# Advocacia-Geral da União                           Advocacia-Geral da União - Unidades com vínculo...       376.672909
# Banco Central do Brasil - Orcamento Fiscal         Banco Central do Brasil - Orçamento Fiscal e Se...       351.543182
# Controladoria Geral da União                       Controladoria-Geral da União - Unidades com vín...       683.250000
# Ministério da Agricultura, Pecuária e Abastecim... Companhia Nacional de Abastecimento                      208.040909
#                                                    Empresa Brasileira de Pesquisa Agropecuária              341.758182
# ...                                                                                                                ...
# ...

# %%
# Indexação por orgaos com soma do valor de transacao
pd.pivot_table(df,values="Valor_Transacao",  index=["Orgao_Superior", "Orgao"], aggfunc="sum", margins=True)
# Out:
#                                                                                                        Valor_Transacao
# Orgao_Superior                                     Orgao
# Advocacia-Geral da União                           Advocacia-Geral da União - Unidades com vínculo...         20717.01
# Banco Central do Brasil - Orcamento Fiscal         Banco Central do Brasil - Orçamento Fiscal e Se...         23201.85
# Controladoria Geral da União                       Controladoria-Geral da União - Unidades com vín...          2733.00
# Ministério da Agricultura, Pecuária e Abastecim... Companhia Nacional de Abastecimento                        11442.25
#                                                    Empresa Brasileira de Pesquisa Agropecuária                26315.38
# ...                                                                                                                ...
# ...

# %%
# referência cruzada entre Orgao_Superior e Orgao com destaque para soma
pd.crosstab(df["Orgao_Superior"],df["Orgao"],aggfunc="sum", values=df["Valor_Transacao"])
# Out:
# Orgao                                               Advocacia-Geral da União - Unidades com vínculo direto  \
# Orgao_Superior
# Advocacia-Geral da União                                                                     20717.01
# Banco Central do Brasil - Orcamento Fiscal                                                        NaN
# Controladoria Geral da União                                                                      NaN
# Ministério da Agricultura, Pecuária e Abastecim...                                                NaN
# Ministério da Ciência, Tecnologia, Inovações                                                      NaN
# Ministério da Defesa                                                                              NaN
# Ministério da Economia                                                                            NaN
# Ministério da Educação                                                                            NaN
# ...
